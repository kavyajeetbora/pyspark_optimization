# %%
from pyspark.sql import functions as F
from delta.tables import DeltaTable

# %%
table_path = "abfss://testcontainer@storageinswa01us2dev.dfs.core.windows.net/delta_lake_tutorial/processed_data/"

delta_table = DeltaTable.forPath(spark, table_path)

# %%
delta_table.toDF().count()

# %%
display(delta_table.history().limit(5))

# %% [markdown]
# ## Time travelling to previous version

# %%
delta_table.restoreToVersion(2)

# %%
display(delta_table.history().limit(5))

# %%
delta_table.toDF().count()

# %% [markdown]
# The count changed from `4 M` to `200` records after restore

# %%
display(delta_table.history().orderBy(F.col('timestamp').asc()).limit(5))

# %% [markdown]
# ## Restore by TimeStamp

# %%
delta_table.restoreToTimestamp('2026-09-14 19:21:55.411')

# %%
delta_table.toDF().count()
